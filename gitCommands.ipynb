# %%
from google.colab import drive
drive.mount('/content/gdrive');
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/DMT_Project
# Out:
# /content/gdrive/My Drive/Colab Notebooks/DMT_Project

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Colab Notebooks/DMT_Project

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Colab Notebooks/DMT_Project/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://Manoj1247:Isrop1247*@github.com/Manoj1247/HeartDiseaseClassification.git
# !git remote -v
# Out:
# origin	https://Manoj1247:Isrop1247*@github.com/Manoj1247/HeartDiseaseClassification.git (fetch)
# origin	https://Manoj1247:Isrop1247*@github.com/Manoj1247/HeartDiseaseClassification.git (push)

# %%
# !git config --global user.email 'manojsaikalaganti@gmail.com'
# !git config --global user.name 'Manoj1247'

# %%
token = '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'
username = 'Manoj1247'
repo = 'HeartDiseaseCla'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 10a1415] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://Manoj1247:Isrop1247*@github.com/Manoj1247/HeartDiseaseClassification.git/'
